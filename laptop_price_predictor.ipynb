# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %% [markdown]
# NOTE THE DATASET IS TOO SMALL.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicated rows.

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# There are no missing values in this dataset.

# %% [markdown]
# unnamed 0 is a useless column,.. so remove it.

# %%
df.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %% [markdown]
# Remove the "GB" from RAM feature and remove the "kg" from Weight feature.

# %%
df['Ram'] = df['Ram'].str.replace("GB","")
df['Weight'] = df['Weight'].str.replace("kg","")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-346-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# The distribution of data is quite skewed(uneven distribution).

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# Check whether Company has influence over prices of laptops.

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Razer is the most costliest laptop, followed by LG and Apple. Its clear that Companies have an influence over Prices of the laptops.

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Workstations , ultrabooks are the types of laptop which are most expensive, thus TypeName feature influences Price.

# %%
sns.distplot(df['Inches'])
# Out:
# <ipython-input-351-51888cb550e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [markdown]
# Inches affects price attribute

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# the common terms in ScreenResolution feature are : 'Touchscreen' , 'Ips' , X and Y resolution. We need to feature engineer on these attributes.

# %%
df["Touchscreen"] = df['ScreenResolution'].apply(lambda x : 1 if 'Touchscreen' in x else 0)

# %% [markdown]
# the Touchscreen feature shows that if the laptop has Touchscreen display then it is 1 else 0

# %%
df.sample(5)  #to select 5 random rows from the dataset
# Out:
#      Company  TypeName  Inches                     ScreenResolution  \
# 193   Lenovo  Notebook    17.3                             1600x900
# 989     Dell  Notebook    14.0                    Full HD 1920x1080
# 949     Acer  Notebook    14.0                             1366x768
# 830    Razer    Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
# 1222      HP  Notebook    15.6                    Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 193             Intel Core i5 8250U 1.6GHz    8           256GB SSD
# 989             Intel Core i5 7200U 2.5GHz    8           128GB SSD
# 949   Intel Celeron Dual Core N3060 1.6GHz    4  32GB Flash Storage
# 830            Intel Core i7 7820HK 2.9GHz   32           512GB SSD
# 1222           AMD A12-Series 9720P 2.7GHz    6             1TB HDD
#
#                           Gpu       OpSys  Weight      Price  Touchscreen
# ...

# %%
df['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %% [markdown]
# Touchscreen feature has an influnce over price

# %%
df["Ips"] = df['ScreenResolution'].apply(lambda x : 1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#       Company            TypeName  Inches  \
# 684    Lenovo  2 in 1 Convertible    13.3
# 874   Samsung           Ultrabook    15.0
# 1239   Lenovo            Notebook    13.3
# 1176   Lenovo            Notebook    15.6
# 1119     Asus              Gaming    17.3
#
#                                ScreenResolution                          Cpu  \
# 684   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 874                           Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 1239                IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 1176                          Full HD 1920x1080   Intel Core i7 6500U 2.5GHz
# 1119                          Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 684     8             512GB SSD   Intel UHD Graphics 620  Windows 10    1.19
# 874    16             256GB SSD     Nvidia GeForce 940MX  Windows 10    1.23
# ...

# %%
df['Ips'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %% [markdown]
# Touchscreen feature has an influnce over price

# %% [markdown]
# our next feature is x-y screen resolution

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %% [markdown]
# To find correleation between features and price

# %%
df.corr()['Price']
# Out:
# <ipython-input-369-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# Ram , X_res, Y_res have good corelation with price, ie., Strong and meaningful relationship between 2 variables.

# %% [markdown]
# We can add a new feature called PPI (Pixels per inch). A higher PPI value generally means that the screen has more pixels per inch, resulting in a higher resolution display. Thus more price. It is calculated as
# ![Screenshot_5.png](data:image/png;base64,...)

# %%
df['ppi'] = (df['X_res']**2 + df['Y_res'])**0.5/df['Inches'].astype('float')

# %%
df.corr()['Price']
# Out:
# <ipython-input-371-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.474960
# Name: Price, dtype: float64

# %% [markdown]
# PPI has good corelation with Price

# %%
df.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  192.504698
# 1  108.294170
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample(6)
# Out:
#      Company   TypeName                                   Cpu  Ram     Memory  \
# 576  Toshiba  Ultrabook            Intel Core i7 7500U 2.7GHz   16  512GB SSD
# 305   Lenovo   Notebook  Intel Pentium Quad Core N4200 1.1GHz    4    1TB HDD
# 254     Acer   Notebook            Intel Core i3 7130U 2.7GHz    4  256GB SSD
# 381   Lenovo   Notebook              Intel Core i3 6006U 2GHz    4  128GB SSD
# 274  Toshiba   Notebook            Intel Core i7 6500U 2.5GHz    8  500GB HDD
# 864     Dell  Ultrabook            Intel Core i7 7660U 2.5GHz   16  512GB SSD
#
#                               Gpu       OpSys  Weight        Price  \
# 576         Intel HD Graphics 620  Windows 10    1.24   99367.2000
# 305         Intel HD Graphics 505       No OS    2.20   19180.2672
# 254          Nvidia GeForce MX130  Windows 10    3.00   37402.5600
# 381         Intel HD Graphics 520       No OS    1.85   21498.4800
# 274           Nvidia GeForce 930M  Windows 10    2.20   43263.3600
# ...

# %% [markdown]
# There are many rows with intel i5,i7,i3 and 'amd' and 'others'. So We make 5 columns with intel i5,i7,i3,amd and other intel processors.

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  else:
    if text.split()[0] == 'Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(6)
# Out:
#       Company   TypeName                          Cpu  Ram  \
# 416      Dell   Notebook     Intel Core i3 6006U 2GHz    4
# 1212      MSI     Gaming  Intel Core i7 6700HQ 2.6GHz   16
# 746   Samsung  Ultrabook   Intel Core i7 7500U 2.7GHz   16
# 669      Acer   Notebook     Intel Core i3 6006U 2GHz    4
# 342        HP   Notebook   Intel Core i3 7100U 2.4GHz    8
# 479   Toshiba   Notebook   Intel Core i5 7200U 2.5GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 416              128GB SSD    Intel HD Graphics 520  Windows 10    1.65
# 1212  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10    2.43
# 746              256GB SSD    Intel HD Graphics 620  Windows 10    0.81
# 669              128GB SSD    Intel HD Graphics 520       Linux    2.10
# 342                1TB HDD    Nvidia GeForce 930MX   Windows 10    2.10
# 479              256GB SSD    Intel HD Graphics 620  Windows 10    1.05
#
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# the cpu brand also influences the Price

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  192.504698  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  108.294170  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  123.094951  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  187.033278  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  192.504698  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# RAM INFLUENCES PRICE

# %%
df2 = df.copy()
df2.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  192.504698  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  108.294170  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  123.094951  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  187.033278  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  192.504698  Intel Core i5

# %%
df2['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %% [markdown]
# There are mainly 4 terms in Memory feature: HDD,SSD,Hybrid,Flash_Storage. So we divide Memory into these 4 features.
#
# We convert TB to GB then remove the terms

# %%
# Extract capacities and types, convert to GB
df2['Memory'] = df2['Memory'].str.replace('GB', '').str.replace('TB', '000')  # Remove GB and convert TB to GB
df2['Memory'] = df2['Memory'].str.split('+')

# Initialize columns
df2['HDD'] = 0
df2['SSD'] = 0
df2['Hybrid'] = 0
df2['Flash_Storage'] = 0

# Loop through rows to fill columns
for index, row in df2.iterrows():
    for item in row['Memory']:
        item = item.strip()
        if 'HDD' in item:
            df2.at[index, 'HDD'] = int(float(item.replace('HDD', '').strip()))
        elif 'SSD' in item:
            df2.at[index, 'SSD'] = int(float(item.replace('SSD', '').strip()))
        elif 'Hybrid' in item:
            df2.at[index, 'Hybrid'] = int(float(item.replace('Hybrid', '').strip()))
        elif 'Flash Storage' in item:
            df2.at[index, 'Flash_Storage'] = int(float(item.replace('Flash Storage', '').strip()))

# Drop the original 'Memory' column
df2.drop(columns=['Memory'], inplace=True)

# %%
df2.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  192.504698  Intel Core i5    0  128       0
# 1   47895.5232            0    0  108.294170  Intel Core i5    0    0       0
# 2   30636.0000            0    0  123.094951  Intel Core i5    0  256       0
# 3  135195.3360            0    1  187.033278  Intel Core i7    0  512       0
# 4   96095.8080            0    1  192.504698  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Ram            1303 non-null   int32
#  3   Gpu            1303 non-null   object
#  4   OpSys          1303 non-null   object
#  5   Weight         1303 non-null   float32
#  6   Price          1303 non-null   float64
#  7   Touchscreen    1303 non-null   int64
#  8   Ips            1303 non-null   int64
#  9   ppi            1303 non-null   float64
#  10  Cpu brand      1303 non-null   object
#  11  HDD            1303 non-null   int64
#  12  SSD            1303 non-null   int64
#  13  Hybrid         1303 non-null   int64
#  14  Flash_Storage  1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(6), object(5)
# memory usage: 142.6+ KB

# %%
df2.corr()['Price']
# Out:
# <ipython-input-391-1fbd15721134>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.474960
# HDD             -0.094704
# SSD              0.676250
# Hybrid          -0.004769
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %% [markdown]
# since Hybrid and Flash_storage has the lowest corelation drop those 2 features

# %%
df2.drop(columns=['Hybrid','Flash_Storage'],inplace = True)

# %%
df2.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  192.504698  Intel Core i5    0  128
# 1   47895.5232            0    0  108.294170  Intel Core i5    0    0
# 2   30636.0000            0    0  123.094951  Intel Core i5    0  256
# 3  135195.3360            0    1  187.033278  Intel Core i7    0  512
# 4   96095.8080            0    1  192.504698  Intel Core i5    0  256

# %%
df2['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df2['Gpu brand'] = df2['Gpu'].apply(lambda x: x.split()[0])

# %%
df2.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  192.504698  Intel Core i5    0  128
# 1   47895.5232            0    0  108.294170  Intel Core i5    0    0
# 2   30636.0000            0    0  123.094951  Intel Core i5    0  256
# 3  135195.3360            0    1  187.033278  Intel Core i7    0  512
# 4   96095.8080            0    1  192.504698  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df2['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %% [markdown]
# removing ARM since its only 1 row and doesnt matter

# %%
df2 = df2[df2['Gpu brand'] != 'ARM']

# %%
df2['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df2['Gpu brand'],y=df2['Price'])
# Out:
# <Axes: xlabel='Gpu brand', ylabel='Price'>

# %%
df2.drop(columns=['Gpu'],inplace=True)

# %%
df2.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  192.504698  Intel Core i5    0  128     Intel
# 1  108.294170  Intel Core i5    0    0     Intel
# 2  123.094951  Intel Core i5    0  256     Intel
# 3  187.033278  Intel Core i7    0  512       AMD
# 4  192.504698  Intel Core i5    0  256     Intel

# %%
df2['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %% [markdown]
# We'll divide it into 3 features windows, macOS and others

# %%
sns.barplot(x=df2['OpSys'],y=df2['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def cat_os(inp):
  if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
    return "Windows"
  elif inp == 'macOS' or inp == 'Mac OS X':
    return 'Mac'
  else:
    return 'Others/No OS/Linux'

# %%
df2['os'] = df2['OpSys'].apply(cat_os)

# %%
df2.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  192.504698  Intel Core i5    0  128     Intel                 Mac
# 1  108.294170  Intel Core i5    0    0     Intel                 Mac
# 2  123.094951  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  187.033278  Intel Core i7    0  512       AMD                 Mac
# 4  192.504698  Intel Core i5    0  256     Intel                 Mac

# %%
df2.drop(columns=['OpSys'],inplace=True)

# %%
df2.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  192.504698
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  108.294170
# 2      HP   Notebook    8    1.86   30636.0000            0    0  123.094951
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  187.033278
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  192.504698
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.barplot(x=df2['os'],y=df2['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.distplot(df2['Weight'])
# Out:
# <ipython-input-411-1f553f986949>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df2['Weight'],y=df2['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df2.corr()['Price']
# Out:
# <ipython-input-413-1fbd15721134>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()['Price']
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.476565
# HDD           -0.095153
# SSD            0.676113
# Name: Price, dtype: float64

# %% [markdown]
# Weight feature has relatively better correlation compared to other features,.. so we'll keep it

# %%
df2.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  192.504698
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  108.294170
# 2      HP   Notebook    8    1.86   30636.0000            0    0  123.094951
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  187.033278
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  192.504698
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sns.heatmap(df2.corr())
# Out:
# <ipython-input-415-28890f610699>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr())
# <Axes: >

# %% [markdown]
# from the above figure we understand there are very less corelation between features. this is good!
#
# b/w columns:
# darker colours - good
# lighter colours - bad
#
# if we find a lighter colour like white... we have to remove it or mix it with the corresponding column, thereby reducing multicollinearity, overfitting, model complexity ,...etc.

# %%
sns.distplot(df2['Price'])
# Out:
# <ipython-input-416-7185c39ae3af>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# Since the target attribute has skewed distribution of data we need to apply log transformation inorder to stabilize variance, make data more symmetrical, and reduce the impact of extreme values or outliers.

# %%
sns.distplot(np.log(df2['Price']))
# Out:
# <ipython-input-417-04699cbf31d9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df2['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# NOTE: while predicting prices... take the inverse log of prices.

# %%
X = df2.drop(columns = ['Price'])
y = np.log(df2['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  192.504698
# 1      Apple           Ultrabook    8    1.34            0    0  108.294170
# 2         HP            Notebook    8    1.86            0    0  123.094951
# 3      Apple           Ultrabook   16    1.83            0    1  187.033278
# 4      Apple           Ultrabook    8    1.37            0    1  192.504698
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  137.162945
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  240.622649
# 1300  Lenovo            Notebook    2    1.50            0    0   97.591506
# 1301      HP            Notebook    6    2.19            0    0   87.582121
# 1302    Asus            Notebook    4    2.20            0    0   87.582121
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0   87.582121
# 1141      MSI              Gaming    8    2.40            0    0  123.094951
# 1049     Asus             Netbook    4    1.20            0    0  117.782852
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  123.094951
# 878      Dell            Notebook    4    2.18            0    0  123.094951
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0   87.582121
# 299      Asus           Ultrabook   16    1.63            0    0  123.094951
# 493      Acer            Notebook    8    2.20            0    0   87.582121
# 527    Lenovo            Notebook    8    2.20            0    0   87.582121
# 1193    Apple           Ultrabook    8    0.92            0    1  192.026040
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# Step 1: Column Transformation (step1):
#
# ColumnTransformer is used to apply transformations to specific columns in the dataset.
# It applies one-hot encoding (OneHotEncoder) to categorical columns at indices [0, 1, 7, 10, 11].
# The remainder parameter is set to 'passthrough,' leaving non-specified columns unchanged.
#
# Step 2: Linear Regression ():
#
# step2 is a linear regression model.
# It fits a linear relationship between input features and the target variable.
# Linear regression is used for regression tasks, such as predicting continuous numerical values.

# %% [markdown]
# **LINEAR REGRESSION**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8082913527456238
# MAE 0.20884994123998718
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
np.exp(0.20884994123998718)
# Out:
# 1.2322600732371685

# %% [markdown]
# np.exp(MAE) --> shows the difference in price b/w predicted and original
#
# here we get a difference of rupees 1.23 , shows the model is quite good.

# %% [markdown]
# We'll try different training models and select the best model with high R2 score and less MAE

# %% [markdown]
# **RIDGE REGRESSION**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8140501238254261
# MAE 0.20783748645593422
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# **LASSO REGRESSION**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8082786399640443
# MAE 0.209798310474777
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# **KNN**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.801772874442628
# MAE 0.1922080331548139

# %% [markdown]
# **Decision Tree**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8483521208298961
# MAE 0.17972832702134864

# %% [markdown]
# **SVM**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8209425962079303
# MAE 0.19797832199889814

# %% [markdown]
# **Random Forest**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8853565231568752
# MAE 0.1593848839003593

# %% [markdown]
# **EXTRA TREES**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

step2 = ExtraTreesRegressor(
    n_estimators=100,
    random_state=3,
    bootstrap=False,  # Set bootstrap to False
    max_features=0.75,
    max_depth=15
)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8783560866677596
# MAE 0.15827697103812793

# %% [markdown]
# **AdaBoost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8036107013849303
# MAE 0.22648756793693053
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# **Gradient Boost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8838976373678612
# MAE 0.15920985897833204

# %% [markdown]
# **XgBoost**

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.886719139294693
# MAE 0.15964468309941782

# %% [markdown]
# **VOTING REGRESSOR**

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10, bootstrap=True)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8911912576850154
# MAE 0.15760555329260711

# %% [markdown]
# **Stacking**

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.884387254083248
# MAE 0.16461851994708854

# %% [markdown]
# FROM THE ABOVE MODELS WE IDENTIFY THAT VOTING REGRESSOR GIVES THE BIGGEST R2 SCORE AND LESSER MAE.

# %% [markdown]
# RUN THE PREFFERED TRAINING MODEL TO GENERATE THE RECENT PIPE OBJECT

# %% [markdown]
# EXPORTING THE MODEL

# %%
import pickle

pickle.dump(df2,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
